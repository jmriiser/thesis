# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

pd.set_option('display.float_format', lambda x: '%.3f' % x)

from src.pipelines import get_num_of_k
from src.utils import plot_missing_percentages, drop_missing_cols, custom_summary
from src.pipelines import LEncoder, variance_threshold_selector
from src.dataloader import  get_raw_data
from src.run import DIAGCOLORS
from src.eval_metrics import calc_confusion

# %%
import os
script_dir = os.path.dirname('')
results_dir = os.path.join(script_dir, 'cluster_output/')
os.makedirs(results_dir, exist_ok=True)

# %%
cats = [
    'DMSEX',
    #'PHNYHA', 
    'PHSYNA', 'PHCARPYN', 
    'PHSPIYN','PHPERFYN', #'PHOTHYN',
    'PHMH2', 'PHMH6', 'PHMH7', 'PHMH8', 'PHMH9','PHMH10',
    'EKGVOLT', 'DUOTHBIYN',
    'DPD'
]

conts = [
    'DMAGE',
    'ECHLVIDD', #'ECHLVIDS',
    'ECHIVSD', 'ECHLVPW',
    #'ECHLADIA',
    'ECHLAAR', #'ECHLAVOL', 
    'ECHEJFR', 
    #'ECHEA',
    'HEKRRE', 'HEGFRRE', 'HEBNPRE', 'HETNTRE',
    'K/L Ratio'
]

# %% [markdown]
# ## Data Preparation

# %%
from sklearn.model_selection import train_test_split

data = get_raw_data(dataset='./data/data_v2.xlsx', sheet_name='Data')
data = drop_missing_cols(data, 40)

X = data.copy()
X[cats] = X[cats].fillna('Ukjent')
X[cats] = X[cats].astype(str)
y = data.PHDIAG

X, X_test, y, y_test = train_test_split(X, y, test_size=0.1, random_state=0)

y_ca = y.replace('TTR amyloidose', 'CA')
y_ca = y_ca.replace('AL amyloidose', 'CA')
y_ca = y_ca.replace('Annet', 'non-CA')

y_ca_test = y_test.replace('TTR amyloidose', 'CA')
y_ca_test = y_test.replace('AL amyloidose', 'CA')
y_ca_test = y_test.replace('Annet', 'non-CA')

# %%
from sklearn.impute import IterativeImputer
from sklearn.linear_model import BayesianRidge
from sklearn.preprocessing import MinMaxScaler

# Training set
### Continuous
imputer = IterativeImputer(BayesianRidge())
imputer.fit(X[conts])

impute_data = pd.DataFrame(imputer.transform(X[conts]), index=X.index, columns=conts)
normalizer = MinMaxScaler()
normalizer.fit(impute_data)
normalized = pd.DataFrame(normalizer.transform(impute_data), index=X.index, columns=conts)
conts_high_variance = variance_threshold_selector(normalized, .99 * (1 - .99))
post_hv_conts = conts_high_variance.columns

### Categorical
le = LEncoder()
encoded = le.fit_transform(X[cats])
cats_high_variance = variance_threshold_selector(encoded, .75 * (1 - .75))
inverse_cats = le.inverse_transform(cats_high_variance)
post_hv_cats = inverse_cats.columns

new_cats = [*inverse_cats.columns]
new_conts = [*conts_high_variance.columns]

updated_data = pd.concat([conts_high_variance, inverse_cats], axis=1)
cat_cols = list(updated_data.columns.get_indexer(new_cats))

# %%
# Test set, here we only transform 
impute_data_test = pd.DataFrame(imputer.transform(X_test[conts]), index=X_test.index, columns=conts)
normalized_test = pd.DataFrame(normalizer.transform(impute_data_test), index=X_test.index, columns=conts)
conts_hv_test = normalized_test[post_hv_conts]

cat_cols_test = X_test[post_hv_cats]

new_cats_test = [*cat_cols_test.columns]
new_conts_test = [*conts_hv_test.columns]

updated_data_test = pd.concat([conts_hv_test, cat_cols_test], axis=1)
cat_cols_test = list(updated_data_test.columns.get_indexer(new_cats_test))

# %% [markdown]
# # Gower distance

# %%
import gower
from sklearn.manifold import TSNE
#import umap

gd = gower.gower_matrix(updated_data)
gd_test = gower.gower_matrix(updated_data_test)

gow_tsne = TSNE(n_components=2, perplexity=30, random_state=0).fit_transform(gd)
gow_tsne_test = TSNE(n_components=2, perplexity=30, random_state=0).fit_transform(gd_test)
#gow_umap = umap.UMAP(n_neighbors=25, min_dist=0.0, n_components=2, random_state=0).fit_transform(dist_matrix)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/homebrew/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(
# /opt/homebrew/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:795: FutureWarning: The default initialization in TSNE will change from 'random' to 'pca' in 1.2.
#   warnings.warn(
# /opt/homebrew/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:805: FutureWarning: The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#   warnings.warn(

# %% [markdown]
# # FAMD

# %%
import prince

famd = prince.FAMD(n_components=2, n_iter=10,
                   copy=True, check_input=True,
                   engine='auto',random_state=0)

famd = famd.fit(updated_data)
famd_transformed = famd.row_coordinates(updated_data)
famd_transformed_test = famd.row_coordinates(updated_data_test)

# %% [markdown]
# ### Parameter Selection
# Number of K

# %%
num_k = 5

# %%
get_num_of_k(gd, os.path.join(results_dir, 'gower'))
# Out:
# 5

# %%
get_num_of_k(famd_transformed, os.path.join(results_dir, 'famd'))
# Out:
# 5

# %%
from sklearn.neighbors import NearestNeighbors

neigh = NearestNeighbors(n_neighbors=2)
nbrs = neigh.fit(gd)

distances, indices = nbrs.kneighbors(gd)
distances = np.sort(distances, axis=0)
distances = distances[:,1]

plt.plot(distances)

# %% [markdown]
# ### The Models

# %%
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, OPTICS
from kmodes.kprototypes import KPrototypes

models = [
    KPrototypes(n_clusters=num_k, max_iter=200, n_init=15, random_state=0),
    KMeans(n_clusters=num_k, init="k-means++", n_init=50, max_iter=500, random_state=0),
    AgglomerativeClustering(n_clusters=num_k, affinity='precomputed', linkage='complete'),
    DBSCAN(eps=0.8, metric='precomputed', min_samples=5),
    OPTICS(metric='precomputed', min_samples=5)
]

# %%
cols_mask = new_cats+new_conts+['PHDIAG']

kproto_data = X.copy()[cols_mask]
kproto_test = X_test.copy()[cols_mask]

kproto = models[0]
kproto_preds = kproto.fit_predict(updated_data, categorical=cat_cols)
kproto_data['Clusters'] = kproto_preds
kproto_test['Clusters'] = kproto.predict(updated_data_test, categorical=cat_cols)

# %%
kmeans_data = X.copy()[cols_mask]
kmeans_test = X_test.copy()[cols_mask]

kmeans = models[1]
kmeans.fit(famd_transformed)
kmeans_preds = kmeans.predict(famd_transformed)
kmeans_data['Clusters'] = kmeans_preds
kmeans_test['Clusters'] = kmeans.predict(famd_transformed_test)

# %%
agglo_data = X.copy()[cols_mask]
agglo_test = X_test.copy()[cols_mask]

agglo = models[2]
agglo_preds = agglo.fit_predict(gd)
agglo_data['Clusters'] = agglo_preds
agglo_test['Clusters'] = agglo.fit_predict(gd_test)

# %% [raw]
# dbscan_data = X.copy()[cols_mask]
#
# dbsc = models[3]
# dbsc_preds = dbsc.fit_predict(gd)
# dbscan_data['Clusters'] = dbsc_preds

# %%
optics_data = X.copy()[cols_mask]

opt = models[-1]
opt_preds = opt.fit_predict(gd)
optics_data['Clusters'] = opt_preds

# %% [markdown]
# ### Ground truth

# %% [raw]
# ax = famd.plot_row_coordinates(
#     updated_data,
#     ax=None,
#     figsize=(6, 6),
#     x_component=0,
#     y_component=1,
#     #labels=coords.index,
#     color_labels=[f'{t}' for t in y],
#     ellipse_outline=False,
#     ellipse_fill=True,
#     show_points=True
# )
# plt.savefig('truth')

# %% [raw]
# ax = famd.plot_row_coordinates(
#     updated_data,
#     ax=None,
#     figsize=(6, 6),
#     x_component=0,
#     y_component=1,
#     #labels=coords.index,
#     color_labels=[f'{t}' for t in y.replace({'TTR amyloidose': 'CA', 'AL amyloidose': 'CA', 'Annet': 'non-CA'})],
#     ellipse_outline=False,
#     ellipse_fill=True,
#     show_points=True
# )
# plt.savefig('truth_ca')

# %% [raw]
# from matplotlib.lines import Line2D
# legend_elements = [Line2D([0], [0], marker='o', color='w', label='AL',
#                           markerfacecolor='red', markersize=10),
#                    Line2D([0], [0], marker='o', color='w', label='Other',
#                           markerfacecolor='blue', markersize=10),
#                    Line2D([0], [0], marker='o', color='w', label='ATTR',
#                           markerfacecolor='green', markersize=10)]
#
# legend_elements_ca = [Line2D([0], [0], marker='o', color='w', label='CA',
#                           markerfacecolor='red', markersize=10),
#                    Line2D([0], [0], marker='o', color='w', label='non-CA',
#                           markerfacecolor='blue', markersize=10)]
#
# fig = plt.figure(figsize=(12, 9))
# sc = plt.scatter(gow_tsne[:, 0], gow_tsne[:, 1], c=X['PHDIAG'].map(DIAGCOLORS))
# plt.xlabel('Component 1')
# plt.ylabel('Component 2')
# plt.legend(handles=legend_elements)
#
# #plt.savefig('ground_truth_single')
# plt.show()
#
#
# fig = plt.figure(figsize=(12, 9))
# sc = plt.scatter(gow_tsne[:, 0], gow_tsne[:, 1], c=X['PHDIAG'].replace({'TTR amyloidose': 'CA', 'AL amyloidose': 'CA', 'Annet': 'non-CA'}).map({'CA': 'red', 'non-CA':'blue'}))
# plt.xlabel('Component 1')
# plt.ylabel('Component 2')
# plt.legend(handles=legend_elements_ca)
#
# plt.savefig('gower_gt_plot')
# plt.show()

# %% [markdown]
# ### Clusterings

# %% [markdown]
# ## K-Prototype

# %%
fig = plt.figure(figsize=(12, 9))
sc = plt.scatter(famd_transformed[0], famd_transformed[1], c=kproto_preds)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*sc.legend_elements(), title='clusters')

plt.savefig(os.path.join(results_dir, 'gower_kproto_plot'))
plt.show()

# %% [raw]
# for i in range(num_k):
#     print(f'Cluster {i}:', kproto_data.groupby(['Clusters']).get_group(i).groupby('PHDIAG').size())

# %%
kmeans_data.groupby(['Clusters']).get_group(0).std().T
# Out:
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/1459494263.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kmeans_data.groupby(['Clusters']).get_group(0).std().T
# DMAGE         7.290
# ECHIVSD       0.389
# ECHLVPW       0.379
# ECHLAAR       5.852
# ECHEJFR       9.827
# HEKRRE       18.815
# HEGFRRE      14.560
# HEBNPRE    1098.341
# HETNTRE      33.794
# Clusters      0.000
# dtype: float64

# %%
def summarize_clusters(data):
    df = [pd.concat(
            [data.groupby(['Clusters']).get_group(i).median().T, 
             data.groupby(['Clusters']).get_group(i).describe(include='object').T.freq / \
             data.groupby(['Clusters']).get_group(i).describe(include='object').T['count']]
          )  for i in range(len(data.groupby(['Clusters']))) if i in data.Clusters.unique()]
    return pd.DataFrame(df).T

# %%
summarize_clusters(kproto_data)
# Out:
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
#                0         1        2        3        4
# DMAGE     61.000    74.500   76.000   79.000   74.000
# ECHIVSD    1.500     1.250    1.350    1.700    1.500
# ECHLVPW    1.050     1.200    0.900    1.400    1.400
# ECHLAAR   25.000    27.000   29.000   31.000   23.500
# ECHEJFR   55.000    30.000   55.000   34.000   45.000
# HEKRRE    79.000   108.000   95.000  117.000  117.000
# HEGFRRE   84.000    44.000   62.500   55.500   51.000
# HEBNPRE  758.000 19323.000 1917.500 6187.000 2740.000
# HETNTRE   17.500    96.000   42.000   74.500   45.000
# Clusters   0.000     1.000    2.000    3.000    4.000
# DMSEX      0.648     0.700    0.848    0.909    0.727
# PHPERFYN   0.889     0.800    0.804    0.818    0.500
# PHMH2      0.870     0.700    0.891    0.818    0.909
# PHMH6      0.778     0.700    0.804    0.727    0.909
# PHMH7      0.815     0.900    0.609    0.727    0.773
# EKGVOLT    0.889     0.900    0.783    0.591    0.773
# DPD        0.593     0.500    0.457    0.455    0.636
# PHDIAG     0.574     0.500    0.717    0.909    0.455

# %%
summarize_clusters(kproto_test)
# Out:
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
#                 0        1        2
# DMAGE      66.500   74.000   83.500
# ECHIVSD     1.650    1.500    1.450
# ECHLVPW     1.400    0.900    1.350
# ECHLAAR    33.000   29.000   29.000
# ECHEJFR    56.500   47.500   40.000
# HEKRRE     94.000   95.000  106.000
# HEGFRRE    71.500   70.000   61.000
# HEBNPRE  2706.000 1245.000 2477.000
# HETNTRE    40.500   44.000   97.000
# Clusters    0.000    2.000    3.000
# DMSEX       1.000    0.833    1.000
# PHPERFYN    1.000    0.833    0.750
# PHMH2       0.500    0.667    1.000
# PHMH6       1.000    1.000    0.750
# PHMH7       0.500    0.667    0.750
# EKGVOLT     1.000    0.833    0.500
# DPD         0.500    0.333    0.250
# PHDIAG      0.500    0.667    1.000

# %%
data_counts = pd.DataFrame(kproto_data.groupby(['Clusters', 'PHDIAG']).size()).unstack(fill_value=0)
data_counts.plot(kind='bar',figsize=(15, 8), xlabel='Clusters', ylabel='Count')
plt.legend(['AL amyloidose', 'Annet', 'TTR amyloidose'])

plt.savefig(os.path.join(results_dir, 'kproto_clusters'))

# %%
data_counts = pd.DataFrame(kproto_test.groupby(['Clusters', 'PHDIAG']).size()).unstack(fill_value=0)
data_counts.plot(kind='bar',figsize=(15, 8), xlabel='Clusters', ylabel='Count')
plt.legend(['AL amyloidose', 'Annet', 'TTR amyloidose'])
plt.savefig(os.path.join(results_dir, 'kproto_clusters_test'))

# %%
def result_transformer(data):
    data_dict = {}
    for i in range(num_k):
        data_dict[i] = data.copy()
        data_dict[i]['Clusters'] = data_dict[i]['Clusters'].map(lambda c: 1 if c == i else 0)
    return data_dict

# %%
from sklearn.ensemble import RandomForestClassifier
    
train_data = updated_data.copy()
le = LEncoder()
train_data[new_cats] = le.fit_transform(train_data[new_cats])

transformed_clusters = result_transformer(kproto_data)

df = pd.DataFrame([['A', 10, 20, 10, 30], ['B', 20, 25, 15, 25], ['C', 12, 15, 19, 6],
                   ['D', 10, 29, 13, 19]],
                  columns=['Team', 'Round 1', 'Round 2', 'Round 3', 'Round 4'])
# view data
feats = []
weights = []
for i in range(len(transformed_clusters)):
    clf = RandomForestClassifier(random_state=0)
    clf.fit(train_data, transformed_clusters[i].Clusters)

    sorted_most_imp = np.argsort(clf.feature_importances_)[::-1]

    feats.append(np.take_along_axis(
        np.array(train_data.iloc[:, :].columns.tolist()),
        sorted_most_imp, axis=0
    ))

    weights.append(np.take_along_axis(
        np.array(clf.feature_importances_),
        sorted_most_imp, axis=0
    ))

# %%
kproto_data.groupby(['Clusters']).get_group(4).PHDIAG.describe().T
# Out:
# count                 22
# unique                 3
# top       TTR amyloidose
# freq                  10
# Name: PHDIAG, dtype: object

# %%
df_dict = dict(zip(feats[0], [[] for _ in range(len((feats[0])))]))

for feat, we in zip(feats, weights):
    for f, w in zip(feat, we):
        df_dict[f].append(w)

# %%
eeete=[]
for k in df_dict.keys():
    eeete.append([k, *df_dict[k]])

# %%
ft_imp = pd.DataFrame(eeete, columns=['Features', 'Cluster 0', 'Cluster 1', 'Cluster 2', 'Cluster 3', 'Cluster 4'])

# %%
for col, *s in eeete:
    print(col, np.average(s))
# Out:
# DMAGE 0.09497201728278057
# HEGFRRE 0.09599829235759769
# HEKRRE 0.07841614105481992
# PHMH2 0.0883521356213273
# HEBNPRE 0.120059875246376
# HETNTRE 0.08177877099792694
# ECHEJFR 0.08268001640995638
# ECHLAAR 0.06509045719190198
# PHPERFYN 0.043288964949186076
# DPD 0.05166527219804201
# ECHLVPW 0.061517234828592525
# ECHIVSD 0.04822011645861475
# PHMH7 0.0291561896202172
# PHMH6 0.029419095586741585
# EKGVOLT 0.011609470303766328
# DMSEX 0.017775949892152802

# %%
ft_imp
# Out:
#     Features  Cluster 0  Cluster 1  Cluster 2  Cluster 3  Cluster 4
# 0      DMAGE      0.175      0.061      0.090      0.087      0.063
# 1    HEGFRRE      0.171      0.075      0.057      0.053      0.125
# 2     HEKRRE      0.125      0.078      0.052      0.047      0.090
# 3      PHMH2      0.111      0.012      0.208      0.035      0.076
# 4    HEBNPRE      0.084      0.272      0.071      0.094      0.080
# 5    HETNTRE      0.076      0.085      0.066      0.092      0.090
# 6    ECHEJFR      0.049      0.094      0.075      0.126      0.069
# 7    ECHLAAR      0.041      0.045      0.086      0.065      0.088
# 8   PHPERFYN      0.039      0.025      0.034      0.090      0.029
# 9        DPD      0.037      0.049      0.056      0.068      0.049
# 10   ECHLVPW      0.032      0.024      0.084      0.070      0.098
# 11   ECHIVSD      0.028      0.050      0.038      0.057      0.069
# 12     PHMH7      0.017      0.034      0.051      0.030      0.014
# 13     PHMH6      0.007      0.021      0.017      0.060      0.042
# 14   EKGVOLT      0.003      0.014      0.010      0.020      0.011
# 15     DMSEX      0.003      0.063      0.007      0.007      0.008

# %%
ft_imp.plot(
    x='Features',
    kind='barh',
    stacked=False,
    figsize=(9, 14),
    xlabel='Features',
    ylabel='Scores',
    width=0.8,
    colormap='viridis',
    title='Feature Importance Scores for Each Cluster'
)
plt.savefig(os.path.join(results_dir, 'feature_importances'))

# %%
kproto_data.groupby(['Clusters', 'PHDIAG']).count()
# Out:
#                          DMSEX  PHPERFYN  PHMH2  PHMH6  PHMH7  EKGVOLT  DPD  \
# Clusters PHDIAG
# 0        AL amyloidose       9         9      9      9      9        9    9
#          Annet              31        31     31     31     31       31   31
#          TTR amyloidose     14        14     14     14     14       14   14
# 1        AL amyloidose       2         2      2      2      2        2    2
#          Annet               5         5      5      5      5        5    5
#          TTR amyloidose      3         3      3      3      3        3    3
# 2        AL amyloidose       2         2      2      2      2        2    2
#          Annet              11        11     11     11     11       11   11
#          TTR amyloidose     33        33     33     33     33       33   33
# 3        AL amyloidose       1         1      1      1      1        1    1
#          Annet               1         1      1      1      1        1    1
#          TTR amyloidose     20        20     20     20     20       20   20
# 4        AL amyloidose       8         8      8      8      8        8    8
#          Annet               4         4      4      4      4        4    4
#          TTR amyloidose     10        10     10     10     10       10   10
#
#                          DMAGE  ECHIVSD  ECHLVPW  ECHLAAR  ECHEJFR  HEKRRE  \
# Clusters PHDIAG
# 0        AL amyloidose       9        7        7        7        6       7
#          Annet              31       27       24       22       12      31
#          TTR amyloidose     14       13       13       10        9      13
# 1        AL amyloidose       2        2        2        2        2       2
#          Annet               5        5        5        5        4       5
#          TTR amyloidose      3        1        1        0        1       2
# 2        AL amyloidose       2        2        2        2        2       2
#          Annet              11       11        8        9        6      11
#          TTR amyloidose     33       27       15       20       23      33
# 3        AL amyloidose       1        1        1        1        1       1
#          Annet               1        1        1        1        1       1
#          TTR amyloidose     20       17       15       11       13      19
# 4        AL amyloidose       8        5        5        5        4       8
#          Annet               4        4        4        4        2       4
#          TTR amyloidose     10        8        8        5        5      10
#
#                          HEGFRRE  HEBNPRE  HETNTRE
# Clusters PHDIAG
# 0        AL amyloidose         7        7        7
#          Annet                31       30       30
#          TTR amyloidose       13       13       13
# 1        AL amyloidose         2        2        2
#          Annet                 5        5        5
#          TTR amyloidose        1        2        2
# 2        AL amyloidose         2        2        2
#          Annet                11       11       10
#          TTR amyloidose       33       31       30
# 3        AL amyloidose         1        1        1
#          Annet                 1        1        1
#          TTR amyloidose       18       19       16
# 4        AL amyloidose         8        8        8
#          Annet                 4        4        4
#          TTR amyloidose        9        8        9

# %%
kproto_data.groupby(['Clusters', 'DPD']).count()
# Out:
#                                 DMSEX  PHPERFYN  PHMH2  PHMH6  PHMH7  EKGVOLT  \
# Clusters DPD
# 0        2.0                        7         7      7      7      7        7
#          3.0                        6         6      6      6      6        6
#          Ikke testet                8         8      8      8      8        8
#          Normal                    32        32     32     32     32       32
#          Patologisk, uten grad      1         1      1      1      1        1
# 1        2.0                        1         1      1      1      1        1
#          Ikke testet                2         2      2      2      2        2
#          Normal                     5         5      5      5      5        5
#          Patologisk, uten grad      2         2      2      2      2        2
# 2        1.0                        6         6      6      6      6        6
#          2.0                        3         3      3      3      3        3
#          3.0                       21        21     21     21     21       21
#          Ikke testet                8         8      8      8      8        8
#          Normal                     7         7      7      7      7        7
#          Patologisk, uten grad      1         1      1      1      1        1
# 3        2.0                       10        10     10     10     10       10
#          3.0                        3         3      3      3      3        3
#          Ikke testet                4         4      4      4      4        4
#          Normal                     1         1      1      1      1        1
#          Patologisk, uten grad      4         4      4      4      4        4
# 4        2.0                        2         2      2      2      2        2
#          3.0                        2         2      2      2      2        2
#          Ikke testet               14        14     14     14     14       14
#          Normal                     3         3      3      3      3        3
#          Patologisk, uten grad      1         1      1      1      1        1
#
#                                 DMAGE  ECHIVSD  ECHLVPW  ECHLAAR  ECHEJFR  \
# Clusters DPD
# 0        2.0                        7        6        6        5        4
#          3.0                        6        6        6        4        5
#          Ikke testet                8        7        6        7        7
#          Normal                    32       27       25       22       11
#          Patologisk, uten grad      1        1        1        1        0
# 1        2.0                        1        1        1        0        1
#          Ikke testet                2        2        2        2        2
#          Normal                     5        5        5        5        4
#          Patologisk, uten grad      2        0        0        0        0
# 2        1.0                        6        6        5        5        4
#          2.0                        3        3        2        2        3
#          3.0                       21       16        8       13       15
#          Ikke testet                8        7        3        4        4
#          Normal                     7        7        7        7        4
#          Patologisk, uten grad      1        1        0        0        1
# 3        2.0                       10        9        8        7        6
#          3.0                        3        3        3        2        3
#          Ikke testet                4        3        3        2        3
#          Normal                     1        1        1        1        1
#          Patologisk, uten grad      4        3        2        1        2
# 4        2.0                        2        2        2        2        1
#          3.0                        2        1        1        0        0
#          Ikke testet               14       11       11        9        7
#          Normal                     3        3        3        3        3
#          Patologisk, uten grad      1        0        0        0        0
#
#                                 HEKRRE  HEGFRRE  HEBNPRE  HETNTRE  PHDIAG
# Clusters DPD
# 0        2.0                         7        7        7        7       7
#          3.0                         6        6        6        6       6
#          Ikke testet                 7        7        7        7       8
#          Normal                     31       31       30       30      32
#          Patologisk, uten grad       0        0        0        0       1
# 1        2.0                         1        1        1        1       1
#          Ikke testet                 2        2        2        2       2
#          Normal                      5        5        5        5       5
#          Patologisk, uten grad       1        0        1        1       2
# 2        1.0                         6        6        6        6       6
#          2.0                         3        3        3        3       3
#          3.0                        21       21       19       19      21
#          Ikke testet                 8        8        8        8       8
#          Normal                      7        7        7        6       7
#          Patologisk, uten grad       1        1        1        0       1
# 3        2.0                         9        9        9        9      10
#          3.0                         3        3        3        2       3
#          Ikke testet                 4        4        4        4       4
#          Normal                      1        1        1        1       1
#          Patologisk, uten grad       4        3        4        2       4
# 4        2.0                         2        2        2        2       2
#          3.0                         2        2        2        2       2
#          Ikke testet                14       14       13       14      14
#          Normal                      3        3        3        3       3
#          Patologisk, uten grad       1        0        0        0       1

# %%
kproto_data.groupby(['Clusters']).describe(include='object').T
# Out:
# Clusters              0            1               2               3  \
# DMSEX    count       54           10              46              22
#          unique       2            2               2               2
#          top       Mann       Kvinne            Mann            Mann
#          freq        35            7              39              20
# PHPERFYN count       54           10              46              22
#          unique       3            2               3               3
#          top        Nei           Ja             Nei              Ja
#          freq        48            8              37              18
# PHMH2    count       54           10              46              22
#          unique       2            2               2               2
#          top     Ukjent       Ukjent    Atrieflimmer    Atrieflimmer
#          freq        47            7              41              18
# PHMH6    count       54           10              46              22
#          unique       2            2               2               2
#          top     Ukjent  Hjertesvikt          Ukjent     Hjertesvikt
#          freq        42            7              37              16
# PHMH7    count       54           10              46              22
#          unique       2            2               2               2
#          top     Ukjent    Hypertoni       Hypertoni          Ukjent
#          freq        44            9              28              16
# EKGVOLT  count       54           10              46              22
#          unique       3            2               2               3
#          top        Nei          Nei             Nei             Nei
#          freq        48            9              36              13
# DPD      count       54           10              46              22
#          unique       5            4               6               5
#          top     Normal       Normal             3.0             2.0
#          freq        32            5              21              10
# PHDIAG   count       54           10              46              22
#          unique       3            3               3               3
#          top      Annet        Annet  TTR amyloidose  TTR amyloidose
#          freq        31            5              33              20
#
# Clusters                      4
# DMSEX    count               22
#          unique               2
#          top               Mann
#          freq                16
# PHPERFYN count               22
#          unique               3
#          top                 Ja
#          freq                11
# PHMH2    count               22
#          unique               2
#          top             Ukjent
#          freq                20
# PHMH6    count               22
#          unique               2
#          top             Ukjent
#          freq                20
# PHMH7    count               22
#          unique               2
#          top             Ukjent
#          freq                17
# EKGVOLT  count               22
#          unique               3
#          top                Nei
#          freq                17
# DPD      count               22
#          unique               5
#          top        Ikke testet
#          freq                14
# PHDIAG   count               22
#          unique               3
#          top     TTR amyloidose
#          freq                10

# %% [markdown]
# ## K-Means

# %%
fig = plt.figure(figsize=(12, 9))
sc = plt.scatter(famd_transformed[ 0], famd_transformed[1], c=kmeans_preds)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*sc.legend_elements(), title='clusters')
plt.savefig(os.path.join(results_dir, 'gower_kmeans_plot'))
plt.show()

# %%
summarize_clusters(kmeans_data)
# Out:
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
#                 0         1        2       3        4
# DMAGE      75.500    69.000   82.000  56.000   72.000
# ECHIVSD     1.500     1.250    1.650   1.200    1.450
# ECHLVPW     1.100     1.200    1.500   1.000    1.100
# ECHLAAR    30.500    24.000   31.000  24.000   24.000
# ECHEJFR    50.500    44.000   34.500  55.000   50.000
# HEKRRE     92.000   397.000  117.500  79.000  112.000
# HEGFRRE    68.000    15.500   51.000  88.000   51.000
# HEBNPRE  1346.000 35000.000 6687.000 493.500 2780.000
# HETNTRE    42.000   232.500   71.000  17.000   44.000
# Clusters    0.000     1.000    2.000   3.000    4.000
# DMSEX       0.917     0.500    0.840   0.632    0.568
# PHPERFYN    0.854     0.500    0.760   0.921    0.514
# PHMH2       0.771     0.833    0.800   0.842    0.811
# PHMH6       0.812     0.500    0.680   0.947    0.595
# PHMH7       0.688     0.667    0.520   0.789    0.514
# EKGVOLT     0.729     1.000    0.560   0.921    0.892
# DPD         0.479     0.500    0.280   0.605    0.486
# PHDIAG      0.792     0.333    0.880   0.553    0.459

# %%
kmeans_data.groupby(['Clusters']).get_group(4).describe(include='object').T
# Out:
#          count unique     top freq
# DMSEX       37      2    Mann   21
# PHPERFYN    37      3     Nei   19
# PHMH2       37      2  Ukjent   30
# PHMH6       37      2  Ukjent   22
# PHMH7       37      2  Ukjent   19
# EKGVOLT     37      3     Nei   33
# DPD         37      6  Normal   18
# PHDIAG      37      3   Annet   17

# %%
data_counts = pd.DataFrame(kmeans_data.groupby(['Clusters', 'PHDIAG']).size()).unstack(fill_value=0)
data_counts.plot(kind='bar',figsize=(15, 8), xlabel='Clusters', ylabel='Count')
plt.legend(['AL amyloidose', 'Annet', 'TTR amyloidose'])
plt.savefig(os.path.join(results_dir, 'kmeans_clusters'))

# %%
data_counts = pd.DataFrame(kmeans_test.groupby(['Clusters', 'PHDIAG']).size()).unstack(fill_value=0)
data_counts.plot(kind='bar',figsize=(15, 8), xlabel='Clusters', ylabel='Count')
plt.legend(['AL amyloidose', 'Annet', 'TTR amyloidose'])
plt.savefig(os.path.join(results_dir, 'kmeans_clusters_test'))

# %%
kmeans_data.groupby(['Clusters', 'PHDIAG']).count()
# Out:
#                          DMSEX  PHPERFYN  PHMH2  PHMH6  PHMH7  EKGVOLT  DPD  \
# Clusters PHDIAG
# 0        Annet              10        10     10     10     10       10   10
#          TTR amyloidose     38        38     38     38     38       38   38
# 1        AL amyloidose       2         2      2      2      2        2    2
#          Annet               2         2      2      2      2        2    2
#          TTR amyloidose      2         2      2      2      2        2    2
# 2        AL amyloidose       1         1      1      1      1        1    1
#          Annet               2         2      2      2      2        2    2
#          TTR amyloidose     22        22     22     22     22       22   22
# 3        AL amyloidose       8         8      8      8      8        8    8
#          Annet              21        21     21     21     21       21   21
#          TTR amyloidose      9         9      9      9      9        9    9
# 4        AL amyloidose      11        11     11     11     11       11   11
#          Annet              17        17     17     17     17       17   17
#          TTR amyloidose      9         9      9      9      9        9    9
#
#                          DMAGE  ECHIVSD  ECHLVPW  ECHLAAR  ECHEJFR  HEKRRE  \
# Clusters PHDIAG
# 0        Annet              10       10        8        9        7      10
#          TTR amyloidose     38       31       24       23       25      37
# 1        AL amyloidose       2        2        2        2        2       2
#          Annet               2        2        2        2        2       2
#          TTR amyloidose      2        2        2        1        1       2
# 2        AL amyloidose       1        1        1        1        1       1
#          Annet               2        2        2        2        2       2
#          TTR amyloidose     22       17       12       10       15      21
# 3        AL amyloidose       8        7        7        7        7       7
#          Annet              21       19       17       15        7      21
#          TTR amyloidose      9        8        8        7        6       9
# 4        AL amyloidose      11        7        7        7        5      10
#          Annet              17       15       13       13        7      17
#          TTR amyloidose      9        8        6        5        4       8
#
#                          HEGFRRE  HEBNPRE  HETNTRE
# Clusters PHDIAG
# 0        Annet                10       10       10
#          TTR amyloidose       37       35       35
# 1        AL amyloidose         2        2        2
#          Annet                 2        2        2
#          TTR amyloidose        2        2        2
# 2        AL amyloidose         1        1        1
#          Annet                 2        2        2
#          TTR amyloidose       18       20       16
# 3        AL amyloidose         7        7        7
#          Annet                21       20       20
#          TTR amyloidose        9        9        9
# 4        AL amyloidose        10       10       10
#          Annet                17       17       16
#          TTR amyloidose        8        7        8

# %%
kmeans_data.groupby(['Clusters', 'DPD']).count()
# Out:
#                                 DMSEX  PHPERFYN  PHMH2  PHMH6  PHMH7  EKGVOLT  \
# Clusters DPD
# 0        1.0                        5         5      5      5      5        5
#          2.0                        6         6      6      6      6        6
#          3.0                       23        23     23     23     23       23
#          Ikke testet                9         9      9      9      9        9
#          Normal                     4         4      4      4      4        4
#          Patologisk, uten grad      1         1      1      1      1        1
# 1        2.0                        2         2      2      2      2        2
#          Ikke testet                3         3      3      3      3        3
#          Normal                     1         1      1      1      1        1
# 2        2.0                        7         7      7      7      7        7
#          3.0                        5         5      5      5      5        5
#          Ikke testet                4         4      4      4      4        4
#          Normal                     2         2      2      2      2        2
#          Patologisk, uten grad      7         7      7      7      7        7
# 3        2.0                        7         7      7      7      7        7
#          3.0                        2         2      2      2      2        2
#          Ikke testet                6         6      6      6      6        6
#          Normal                    23        23     23     23     23       23
# 4        1.0                        1         1      1      1      1        1
#          2.0                        1         1      1      1      1        1
#          3.0                        2         2      2      2      2        2
#          Ikke testet               14        14     14     14     14       14
#          Normal                    18        18     18     18     18       18
#          Patologisk, uten grad      1         1      1      1      1        1
#
#                                 DMAGE  ECHIVSD  ECHLVPW  ECHLAAR  ECHEJFR  \
# Clusters DPD
# 0        1.0                        5        5        4        4        3
#          2.0                        6        6        5        5        5
#          3.0                       23       17       12       13       15
#          Ikke testet                9        8        6        5        6
#          Normal                     4        4        4        4        3
#          Patologisk, uten grad      1        1        1        1        0
# 1        2.0                        2        2        2        1        1
#          Ikke testet                3        3        3        3        3
#          Normal                     1        1        1        1        1
# 2        2.0                        7        6        5        4        5
#          3.0                        5        5        3        3        4
#          Ikke testet                4        3        3        3        4
#          Normal                     2        2        2        2        2
#          Patologisk, uten grad      7        4        2        1        3
# 3        2.0                        7        6        6        5        4
#          3.0                        2        2        2        2        2
#          Ikke testet                6        5        4        5        6
#          Normal                    23       21       20       17        8
# 4        1.0                        1        1        1        1        1
#          2.0                        1        1        1        1        0
#          3.0                        2        2        1        1        2
#          Ikke testet               14       11        9        8        4
#          Normal                    18       15       14       14        9
#          Patologisk, uten grad      1        0        0        0        0
#
#                                 HEKRRE  HEGFRRE  HEBNPRE  HETNTRE  PHDIAG
# Clusters DPD
# 0        1.0                         5        5        5        5       5
#          2.0                         6        6        6        6       6
#          3.0                        23       23       21       21      23
#          Ikke testet                 9        9        9        9       9
#          Normal                      4        4        4        4       4
#          Patologisk, uten grad       0        0        0        0       1
# 1        2.0                         2        2        2        2       2
#          Ikke testet                 3        3        3        3       3
#          Normal                      1        1        1        1       1
# 2        2.0                         6        6        6        6       7
#          3.0                         5        5        5        4       5
#          Ikke testet                 4        4        4        4       4
#          Normal                      2        2        2        2       2
#          Patologisk, uten grad       7        4        6        3       7
# 3        2.0                         7        7        7        7       7
#          3.0                         2        2        2        2       2
#          Ikke testet                 5        5        5        5       6
#          Normal                     23       23       22       22      23
# 4        1.0                         1        1        1        1       1
#          2.0                         1        1        1        1       1
#          3.0                         2        2        2        2       2
#          Ikke testet                14       14       13       14      14
#          Normal                     17       17       17       16      18
#          Patologisk, uten grad       0        0        0        0       1

# %%
kmeans_data.groupby(['Clusters']).describe(include='object').T
# Out:
# Clusters                      0               1               2       3  \
# DMSEX    count               48               6              25      38
#          unique               2               2               2       2
#          top               Mann            Mann            Mann    Mann
#          freq                44               3              21      24
# PHPERFYN count               48               6              25      38
#          unique               3               2               3       2
#          top                Nei             Nei              Ja     Nei
#          freq                41               3              19      35
# PHMH2    count               48               6              25      38
#          unique               2               2               2       2
#          top       Atrieflimmer          Ukjent    Atrieflimmer  Ukjent
#          freq                37               5              20      32
# PHMH6    count               48               6              25      38
#          unique               2               2               2       2
#          top             Ukjent          Ukjent     Hjertesvikt  Ukjent
#          freq                39               3              17      36
# PHMH7    count               48               6              25      38
#          unique               2               2               2       2
#          top             Ukjent       Hypertoni       Hypertoni  Ukjent
#          freq                33               4              13      30
# EKGVOLT  count               48               6              25      38
#          unique               2               1               3       2
#          top                Nei             Nei             Nei     Nei
#          freq                35               6              14      35
# DPD      count               48               6              25      38
#          unique               6               3               5       4
#          top                3.0     Ikke testet             2.0  Normal
#          freq                23               3               7      23
# PHDIAG   count               48               6              25      38
#          unique               2               3               3       3
#          top     TTR amyloidose  TTR amyloidose  TTR amyloidose   Annet
#          freq                38               2              22      21
#
# Clusters              4
# DMSEX    count       37
#          unique       2
#          top       Mann
#          freq        21
# PHPERFYN count       37
#          unique       3
#          top        Nei
#          freq        19
# PHMH2    count       37
#          unique       2
#          top     Ukjent
#          freq        30
# PHMH6    count       37
#          unique       2
#          top     Ukjent
#          freq        22
# PHMH7    count       37
#          unique       2
#          top     Ukjent
#          freq        19
# EKGVOLT  count       37
#          unique       3
#          top        Nei
#          freq        33
# DPD      count       37
#          unique       6
#          top     Normal
#          freq        18
# PHDIAG   count       37
#          unique       3
#          top      Annet
#          freq        17

# %% [markdown]
# ## Agglomerative

# %%
fig = plt.figure(figsize=(12, 9))
sc = plt.scatter(gow_tsne[:,0], gow_tsne[:,1], c=agglo_preds)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*sc.legend_elements(), title='clusters')
plt.savefig(os.path.join(results_dir, 'gower_agglo_plot'))
plt.show()

# %% [raw]
# for i in range(num_k):
#     print(f'Cluster {i}:', agglo_data.groupby(['Clusters']).get_group(i).groupby('PHDIAG').size())

# %%
summarize_clusters(agglo_data)
# Out:
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
#                 0        1        2        3        4
# DMAGE      78.000   73.000   70.000   73.000   63.000
# ECHIVSD     1.600    1.300    1.600    1.600    1.400
# ECHLVPW     1.200    1.000    1.300    1.400    1.000
# ECHLAAR    31.000   28.000   23.500   25.000   24.000
# ECHEJFR    40.000   53.000   44.000   50.000   55.000
# HEKRRE    108.000   92.500   98.000  112.000   83.000
# HEGFRRE    64.000   68.500   53.000   57.000   76.000
# HEBNPRE  2532.000 1203.500 4346.000 2603.500 1002.000
# HETNTRE    61.000   23.000   61.500   57.000   25.500
# Clusters    0.000    1.000    2.000    3.000    4.000
# DMSEX       0.955    0.710    0.700    1.000    0.531
# PHPERFYN    0.477    0.839    0.500    0.500    0.816
# PHMH2       0.932    0.710    1.000    0.850    0.898
# PHMH6       0.545    0.710    0.700    0.800    0.796
# PHMH7       0.773    0.935    1.000    0.550    1.000
# EKGVOLT     0.682    0.903    1.000    0.500    0.939
# DPD         0.386    0.419    0.500    0.350    0.429
# PHDIAG      0.864    0.484    0.600    0.600    0.469

# %%
data = pd.DataFrame(agglo_data.groupby(['Clusters', 'PHDIAG']).size()).unstack(fill_value=0)
data.plot(kind='bar',figsize=(15, 8), xlabel='Clusters', ylabel='Count')
plt.legend(['AL amyloidose', 'Annet', 'TTR amyloidose'])
plt.savefig(os.path.join(results_dir, 'agglo_clusters'))

# %%
agglo_data.groupby(['Clusters', 'PHDIAG']).count()
# Out:
#                          DMSEX  PHPERFYN  PHMH2  PHMH6  PHMH7  EKGVOLT  DPD  \
# Clusters PHDIAG
# 0        AL amyloidose       1         1      1      1      1        1    1
#          Annet               5         5      5      5      5        5    5
#          TTR amyloidose     38        38     38     38     38       38   38
# 1        AL amyloidose       2         2      2      2      2        2    2
#          Annet              15        15     15     15     15       15   15
#          TTR amyloidose     14        14     14     14     14       14   14
# 2        AL amyloidose       2         2      2      2      2        2    2
#          Annet               6         6      6      6      6        6    6
#          TTR amyloidose      2         2      2      2      2        2    2
# 3        AL amyloidose       5         5      5      5      5        5    5
#          Annet               3         3      3      3      3        3    3
#          TTR amyloidose     12        12     12     12     12       12   12
# 4        AL amyloidose      12        12     12     12     12       12   12
#          Annet              23        23     23     23     23       23   23
#          TTR amyloidose     14        14     14     14     14       14   14
#
#                          DMAGE  ECHIVSD  ECHLVPW  ECHLAAR  ECHEJFR  HEKRRE  \
# Clusters PHDIAG
# 0        AL amyloidose       1        1        1        1        1       1
#          Annet               5        5        3        4        5       5
#          TTR amyloidose     38       29       21       21       23      37
# 1        AL amyloidose       2        2        2        2        2       2
#          Annet              15       15       14       12        6      15
#          TTR amyloidose     14       12        9        9       12      13
# 2        AL amyloidose       2        2        2        2        2       2
#          Annet               6        6        3        4        2       6
#          TTR amyloidose      2        2        1        0        1       2
# 3        AL amyloidose       5        5        5        5        5       5
#          Annet               3        3        3        3        3       3
#          TTR amyloidose     12       11       10        7        7      11
# 4        AL amyloidose      12        7        7        7        5      10
#          Annet              23       19       19       18        9      23
#          TTR amyloidose     14       12       11        9        8      14
#
#                          HEGFRRE  HEBNPRE  HETNTRE
# Clusters PHDIAG
# 0        AL amyloidose         1        1        1
#          Annet                 5        5        5
#          TTR amyloidose       35       35       33
# 1        AL amyloidose         2        2        2
#          Annet                15       15       14
#          TTR amyloidose       13       13       11
# 2        AL amyloidose         2        2        2
#          Annet                 6        6        6
#          TTR amyloidose        2        2        2
# 3        AL amyloidose         5        5        5
#          Annet                 3        3        3
#          TTR amyloidose       10       10       10
# 4        AL amyloidose        10       10       10
#          Annet                23       22       22
#          TTR amyloidose       14       13       14

# %%
agglo_data.groupby(['Clusters', 'DPD']).count()
# Out:
#                                 DMSEX  PHPERFYN  PHMH2  PHMH6  PHMH7  EKGVOLT  \
# Clusters DPD
# 0        2.0                        8         8      8      8      8        8
#          3.0                       17        17     17     17     17       17
#          Ikke testet               12        12     12     12     12       12
#          Normal                     2         2      2      2      2        2
#          Patologisk, uten grad      5         5      5      5      5        5
# 1        1.0                        6         6      6      6      6        6
#          2.0                        3         3      3      3      3        3
#          3.0                        5         5      5      5      5        5
#          Ikke testet                2         2      2      2      2        2
#          Normal                    13        13     13     13     13       13
#          Patologisk, uten grad      2         2      2      2      2        2
# 2        2.0                        1         1      1      1      1        1
#          Ikke testet                4         4      4      4      4        4
#          Normal                     5         5      5      5      5        5
# 3        2.0                        4         4      4      4      4        4
#          3.0                        4         4      4      4      4        4
#          Ikke testet                3         3      3      3      3        3
#          Normal                     7         7      7      7      7        7
#          Patologisk, uten grad      2         2      2      2      2        2
# 4        2.0                        7         7      7      7      7        7
#          3.0                        6         6      6      6      6        6
#          Ikke testet               15        15     15     15     15       15
#          Normal                    21        21     21     21     21       21
#
#                                 DMAGE  ECHIVSD  ECHLVPW  ECHLAAR  ECHEJFR  \
# Clusters DPD
# 0        2.0                        8        7        6        5        5
#          3.0                       17       13        8       12       12
#          Ikke testet               12       10        7        6        8
#          Normal                     2        2        2        2        2
#          Patologisk, uten grad      5        3        2        1        2
# 1        1.0                        6        6        5        5        4
#          2.0                        3        3        2        2        3
#          3.0                        5        4        3        3        4
#          Ikke testet                2        2        2        2        2
#          Normal                    13       13       13       11        6
#          Patologisk, uten grad      2        1        0        0        1
# 2        2.0                        1        1        1        0        1
#          Ikke testet                4        4        2        3        3
#          Normal                     5        5        3        3        1
# 3        2.0                        4        4        4        4        2
#          3.0                        4        4        3        1        3
#          Ikke testet                3        3        3        2        3
#          Normal                     7        7        7        7        7
#          Patologisk, uten grad      2        1        1        1        0
# 4        2.0                        7        6        6        5        4
#          3.0                        6        5        4        3        4
#          Ikke testet               15       11       11       11        7
#          Normal                    21       16       16       15        7
#
#                                 HEKRRE  HEGFRRE  HEBNPRE  HETNTRE  PHDIAG
# Clusters DPD
# 0        2.0                         7        7        7        7       8
#          3.0                        17       17       15       15      17
#          Ikke testet                12       12       12       12      12
#          Normal                      2        2        2        2       2
#          Patologisk, uten grad       5        3        5        3       5
# 1        1.0                         6        6        6        6       6
#          2.0                         3        3        3        3       3
#          3.0                         5        5        5        4       5
#          Ikke testet                 2        2        2        2       2
#          Normal                     13       13       13       12      13
#          Patologisk, uten grad       1        1        1        0       2
# 2        2.0                         1        1        1        1       1
#          Ikke testet                 4        4        4        4       4
#          Normal                      5        5        5        5       5
# 3        2.0                         4        4        4        4       4
#          3.0                         4        4        4        4       4
#          Ikke testet                 3        3        3        3       3
#          Normal                      7        7        7        7       7
#          Patologisk, uten grad       1        0        0        0       2
# 4        2.0                         7        7        7        7       7
#          3.0                         6        6        6        6       6
#          Ikke testet                14       14       13       14      15
#          Normal                     20       20       19       19      21

# %%
agglo_data.groupby(['Clusters']).describe(include='object').T
# Out:
# Clusters                      0             1          2               3  \
# DMSEX    count               44            31         10              20
#          unique               2             2          2               1
#          top               Mann          Mann     Kvinne            Mann
#          freq                42            22          7              20
# PHPERFYN count               44            31         10              20
#          unique               3             2          2               3
#          top                Nei           Nei        Nei              Ja
#          freq                21            26          5              10
# PHMH2    count               44            31         10              20
#          unique               2             2          1               2
#          top       Atrieflimmer  Atrieflimmer     Ukjent          Ukjent
#          freq                41            22         10              17
# PHMH6    count               44            31         10              20
#          unique               2             2          2               2
#          top             Ukjent        Ukjent     Ukjent          Ukjent
#          freq                24            22          7              16
# PHMH7    count               44            31         10              20
#          unique               2             2          1               2
#          top             Ukjent     Hypertoni  Hypertoni          Ukjent
#          freq                34            29         10              11
# EKGVOLT  count               44            31         10              20
#          unique               3             2          1               3
#          top                Nei           Nei        Nei              Ja
#          freq                30            28         10              10
# DPD      count               44            31         10              20
#          unique               5             6          3               5
#          top                3.0        Normal     Normal          Normal
#          freq                17            13          5               7
# PHDIAG   count               44            31         10              20
#          unique               3             3          3               3
#          top     TTR amyloidose         Annet      Annet  TTR amyloidose
#          freq                38            15          6              12
#
# Clusters              4
# DMSEX    count       49
#          unique       2
#          top       Mann
#          freq        26
# PHPERFYN count       49
#          unique       3
#          top        Nei
#          freq        40
# PHMH2    count       49
#          unique       2
#          top     Ukjent
#          freq        44
# PHMH6    count       49
#          unique       2
#          top     Ukjent
#          freq        39
# PHMH7    count       49
#          unique       1
#          top     Ukjent
#          freq        49
# EKGVOLT  count       49
#          unique       3
#          top        Nei
#          freq        46
# DPD      count       49
#          unique       4
#          top     Normal
#          freq        21
# PHDIAG   count       49
#          unique       3
#          top      Annet
#          freq        23

# %%
agglo_data.groupby(['Clusters']).describe()['HEBNPRE']
# Out:
#           count      mean       std     min      25%      50%       75%  \
# Clusters
# 0        41.000  4781.390  5146.616 202.000 1346.000 2532.000  6687.000
# 1        30.000  2308.167  3570.158  49.000  479.250 1203.500  2764.500
# 2        10.000 15253.300 17061.552 560.000 1205.000 4346.000 35000.000
# 3        18.000  4531.611  4248.882 234.000 1497.000 2603.500  6430.750
# 4        45.000  2024.711  2297.487  80.000  401.000 1002.000  2554.000
#
#                max
# Clusters
# 0        18386.000
# 1        19323.000
# 2        35000.000
# 3        13687.000
# 4         9392.000

# %% [markdown]
# ## Density-based

# %% [raw]
# fig = plt.figure(figsize=(12, 9))
# sc = plt.scatter(gow_tsne[:,0], gow_tsne[:,1], c=dbsc_preds)
# plt.xlabel('Component 1')
# plt.ylabel('Component 2')
# plt.legend(*sc.legend_elements(), title='clusters')
# #plt.savefig('ground_truth_single')
# plt.show()

# %%
fig = plt.figure(figsize=(12, 9))
sc = plt.scatter(gow_tsne[:,0], gow_tsne[:,1], c=opt_preds)
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.legend(*sc.legend_elements(), title='clusters')
#plt.savefig('ground_truth_single')
plt.show()

# %% [markdown]
# # Validation

# %%
calc_confusion(kproto_data, y, y_ca, num_k)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.6428571428571429,
#  0.6428571428571429,
#  0.5535714285714286,
#  0.5946102578962619,
#  0.7142857142857143,
#  0.7142857142857143,
#  0.717089947089947,
#  0.7155667049184704)

# %%
calc_confusion(kproto_test, y_test, y_ca_test, num_k)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/homebrew/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.7222222222222222,
#  0.7222222222222222,
#  0.7203703703703703,
#  0.71005291005291,
#  0.0,
#  0.0,
#  0.0,
#  0.0)

# %%
kproto_test
# Out:
#       DMSEX PHPERFYN         PHMH2        PHMH6      PHMH7 EKGVOLT  \
# 60     Mann      Nei        Ukjent       Ukjent  Hypertoni      Ja
# 164    Mann       Ja  Atrieflimmer       Ukjent     Ukjent     Nei
# 72     Mann      Nei  Atrieflimmer       Ukjent     Ukjent     Nei
# 61     Mann      Nei  Atrieflimmer       Ukjent     Ukjent     Nei
# 135    Mann       Ja  Atrieflimmer       Ukjent  Hypertoni     Nei
# 109    Mann       Ja  Atrieflimmer       Ukjent     Ukjent      Ja
# 8      Mann      Nei        Ukjent       Ukjent  Hypertoni     Nei
# 173    Mann       Ja        Ukjent       Ukjent     Ukjent      Ja
# 113    Mann      Nei  Atrieflimmer       Ukjent     Ukjent     Nei
# 98     Mann       Ja        Ukjent       Ukjent     Ukjent     Nei
# 156    Mann       Ja  Atrieflimmer       Ukjent     Ukjent     Nei
# 161    Mann       Ja  Atrieflimmer       Ukjent     Ukjent     Nei
# 6      Mann       Ja        Ukjent       Ukjent     Ukjent     Nei
# 106    Mann      Nei        Ukjent       Ukjent  Hypertoni     Nei
# 198    Mann   Ukjent  Atrieflimmer  Hjertesvikt  Hypertoni  Ukjent
# 102  Kvinne      Nei  Atrieflimmer       Ukjent  Hypertoni     Nei
# 34     Mann       Ja        Ukjent  Hjertesvikt     Ukjent     Nei
# 19     Mann       Ja  Atrieflimmer       Ukjent     Ukjent      Ja
#
#                        DPD  DMAGE  ECHIVSD  ECHLVPW  ECHLAAR  ECHEJFR  HEKRRE  \
# 60                     2.0     76      NaN      NaN      NaN      NaN     NaN
# 164  Patologisk, uten grad     79    1.400    1.200   27.000   45.000  88.000
# 72                  Normal     71    1.400    1.200   32.000   58.000  97.000
# 61             Ikke testet     74    1.500    0.900   29.000   39.000  95.000
# 135                    2.0     62    0.900    0.900   25.000   56.000  98.000
# 109                    1.0     88    2.000    1.400   29.000      NaN  96.000
# 8                      2.0     62    1.900    1.600   34.000   55.000  91.000
# 173                    2.0     82    1.800      NaN      NaN   50.000 217.000
# 113            Ikke testet     82    1.500    1.400      NaN   56.000  88.000
# 98                     1.0     79    1.100    1.100   26.000   66.000 151.000
# 156                    3.0     77    1.600    1.600      NaN      NaN 116.000
# 161                    2.0     65    1.000    1.000   23.000   40.000  97.000
# 6              Ikke testet     75    1.700    1.800   27.000   55.000 338.000
# 106                 Normal     74    1.300      NaN      NaN   30.000 119.000
# 198  Patologisk, uten grad     90    1.700    1.600      NaN   50.000 237.000
# 102                 Normal     60    2.100      NaN   30.000      NaN  72.000
# 34             Ikke testet     67    1.400    1.000   30.000   51.000 126.000
# 19                     3.0     79    1.200    1.300   31.000   30.000 115.000
#
#      HEGFRRE   HEBNPRE  HETNTRE          PHDIAG  Clusters             c2c  \
# 60       NaN       NaN      NaN  TTR amyloidose         2  TTR amyloidose
# 164   72.000  1153.000   76.000  TTR amyloidose         4   AL amyloidose
# 72    67.000       NaN   39.000           Annet         0           Annet
# 61    70.000  8396.000   44.000  TTR amyloidose         2  TTR amyloidose
# 135   71.000   753.000   38.000  TTR amyloidose         2  TTR amyloidose
# 109   61.000  8028.000   94.000  TTR amyloidose         3  TTR amyloidose
# 8     76.000  2706.000   42.000  TTR amyloidose         0           Annet
# 173   24.000  4838.000  229.000   AL amyloidose         4   AL amyloidose
# 113   70.000  1737.000   54.000  TTR amyloidose         2  TTR amyloidose
# 98    37.000 17011.000  281.000   AL amyloidose         4   AL amyloidose
# 156   52.000  4504.000   71.000  TTR amyloidose         4   AL amyloidose
# 161   70.000  2183.000   55.000  TTR amyloidose         3  TTR amyloidose
# 6     14.000 12627.000  352.000   AL amyloidose         4   AL amyloidose
# 106   53.000       NaN  271.000           Annet         2  TTR amyloidose
# 198      NaN       NaN  120.000  TTR amyloidose         3  TTR amyloidose
# 102   79.000   750.000   30.000           Annet         2  TTR amyloidose
# 34    51.000   317.000  169.000   AL amyloidose         4   AL amyloidose
# 19    52.000  2477.000  100.000  TTR amyloidose         3  TTR amyloidose
#
#     c2c_binary
# 60          CA
# 164         CA
# 72          CA
# 61          CA
# 135         CA
# 109         CA
# 8           CA
# 173         CA
# 113         CA
# 98          CA
# 156         CA
# 161         CA
# 6           CA
# 106         CA
# 198         CA
# 102         CA
# 34          CA
# 19          CA

# %%
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score, accuracy_score, precision_score, recall_score, f1_score


def clusters_to_classes(grouping, num_clusters):
    mapping = {}
    for i in range(num_clusters):
        if i in grouping.Clusters.unique():
            mapping[i] = grouping['PHDIAG'].count()[i].idxmax()
    return mapping


def clusters_to_binary(grouping, num_clusters):
    mapping = {}
    for i in range(num_clusters):
        if i in grouping.Clusters.unique():
            filt = mapping[i] = grouping['PHDIAG'].count()[i]
            ca = filt[filt.index != 'Annet'].sum()
            non = filt[filt.index == 'Annet'].sum()

            mapping[i] = 'non-CA' if ca < non else 'CA'

    return mapping

# %%
clusters_to_classes(kproto_test.groupby(['Clusters', 'PHDIAG']), num_k)
# Out:
# {0: 'Annet', 2: 'TTR amyloidose', 3: 'TTR amyloidose', 4: 'AL amyloidose'}

# %%
clusters_to_binary(kproto_test.groupby(['Clusters', 'PHDIAG']), num_k)
# Out:
# {0: 'CA', 2: 'CA', 3: 'CA', 4: 'CA'}

# %%
calc_confusion(kmeans_data, y, y_ca, num_k)
# Out:
# (0.6493506493506493,
#  0.6493506493506493,
#  0.6456715886852872,
#  0.6299095157032033,
#  0.6883116883116883,
#  0.6883116883116883,
#  0.6719365026987532,
#  0.6740776043528337)

# %%
calc_confusion(agglo_data, y, y_ca, num_k)
# Out:
# /opt/homebrew/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.6103896103896104,
#  0.6103896103896104,
#  0.5709235209235209,
#  0.5700058939495559,
#  0.6753246753246753,
#  0.6753246753246753,
#  0.6533549783549784,
#  0.5930701870906435)

# %% [raw]
# calc_confusion(dbscan_data, y, y_ca, num_k)

# %%
optics_found = optics_data[optics_data.Clusters != -1]

calc_confusion(optics_found, y[y.index.isin(optics_found.index)], y_ca[y_ca.index.isin(optics_found.index)], num_k)
# Out:
# /Users/jmriiser/Dev/master_thesis/data_mining_prac/src/eval_metrics.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['c2c'] = data['Clusters'].map(c2c)
# /Users/jmriiser/Dev/master_thesis/data_mining_prac/src/eval_metrics.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['c2c_binary'] = data['Clusters'].map(c2c_binary)
# /opt/homebrew/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.9142857142857143,
#  0.9142857142857143,
#  0.8619981325863678,
#  0.8873716759431046,
#  0.9142857142857143,
#  0.9142857142857143,
#  0.9157796451914099,
#  0.9142857142857143)

# %%
optics_found.groupby(['Clusters']).describe(include='object').T
# Out:
# Clusters                        0       1          2       3
# DMSEX      count               17       5          5       8
#            unique               1       1          1       1
#            top               Mann    Mann       Mann  Kvinne
#            freq                17       5          5       8
# PHPERFYN   count               17       5          5       8
#            unique               1       1          1       1
#            top                Nei     Nei        Nei     Nei
#            freq                17       5          5       8
# PHMH2      count               17       5          5       8
#            unique               2       1          1       1
#            top       Atrieflimmer  Ukjent     Ukjent  Ukjent
#            freq                14       5          5       8
# PHMH6      count               17       5          5       8
#            unique               1       1          1       2
#            top             Ukjent  Ukjent     Ukjent  Ukjent
#            freq                17       5          5       5
# PHMH7      count               17       5          5       8
#            unique               1       1          1       2
#            top             Ukjent  Ukjent  Hypertoni  Ukjent
#            freq                17       5          5       7
# EKGVOLT    count               17       5          5       8
#            unique               2       1          1       1
#            top                Nei     Nei        Nei     Nei
#            freq                14       5          5       8
# DPD        count               17       5          5       8
#            unique               2       1          1       1
#            top                3.0  Normal     Normal  Normal
#            freq                14       5          5       8
# PHDIAG     count               17       5          5       8
#            unique               2       2          2       1
#            top     TTR amyloidose   Annet      Annet   Annet
#            freq                16       4          4       8
# c2c        count               17       5          5       8
#            unique               1       1          1       1
#            top     TTR amyloidose   Annet      Annet   Annet
#            freq                17       5          5       8
# c2c_binary count               17       5          5       8
#            unique               1       1          1       1
#            top                 CA  non-CA     non-CA  non-CA
#            freq                17       5          5       8

# %%
summarize_clusters(optics_found)
# Out:
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
# /var/folders/vs/j6yb25ns4dqdm1ydd9mjyzgw0000gn/T/ipykernel_73448/2463100555.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   [data.groupby(['Clusters']).get_group(i).median().T,
#                   0       1       2       3
# DMAGE        76.000  55.000  58.000  66.500
# ECHIVSD       1.800   1.150   1.200   2.000
# ECHLVPW       1.050   0.900   1.000   1.300
# ECHLAAR      31.500  26.000  23.000  22.000
# ECHEJFR      42.500     NaN  50.000  55.500
# HEKRRE       91.000  80.000  86.000  93.000
# HEGFRRE      68.000  96.000  84.000  56.000
# HEBNPRE    1943.000 409.000 191.000 967.000
# HETNTRE      53.500  17.000   7.000  17.000
# Clusters      0.000   1.000   2.000   3.000
# DMSEX         1.000   1.000   1.000   1.000
# PHPERFYN      1.000   1.000   1.000   1.000
# PHMH2         0.824   1.000   1.000   1.000
# PHMH6         1.000   1.000   1.000   0.625
# PHMH7         1.000   1.000   1.000   0.875
# EKGVOLT       0.824   1.000   1.000   1.000
# DPD           0.824   1.000   1.000   1.000
# PHDIAG        0.941   0.800   0.800   1.000
# c2c           1.000   1.000   1.000   1.000
# c2c_binary    1.000   1.000   1.000   1.000

# %%
optics_found.groupby(['Clusters', 'PHDIAG']).count()
# Out:
#                          DMSEX  PHPERFYN  PHMH2  PHMH6  PHMH7  EKGVOLT  DPD  \
# Clusters PHDIAG
# 0        Annet               1         1      1      1      1        1    1
#          TTR amyloidose     16        16     16     16     16       16   16
# 1        AL amyloidose       1         1      1      1      1        1    1
#          Annet               4         4      4      4      4        4    4
# 2        AL amyloidose       1         1      1      1      1        1    1
#          Annet               4         4      4      4      4        4    4
# 3        Annet               8         8      8      8      8        8    8
#
#                          DMAGE  ECHIVSD  ECHLVPW  ECHLAAR  ECHEJFR  HEKRRE  \
# Clusters PHDIAG
# 0        Annet               1        1        0        1        1       1
#          TTR amyloidose     16       10        6        7       11      16
# 1        AL amyloidose       1        1        1        1        0       1
#          Annet               4        3        3        3        0       4
# 2        AL amyloidose       1        1        1        1        1       1
#          Annet               4        4        4        2        1       4
# 3        Annet               8        6        5        4        2       8
#
#                          HEGFRRE  HEBNPRE  HETNTRE  c2c  c2c_binary
# Clusters PHDIAG
# 0        Annet                 1        1        1    1           1
#          TTR amyloidose       16       14       15   16          16
# 1        AL amyloidose         1        1        1    1           1
#          Annet                 4        4        4    4           4
# 2        AL amyloidose         1        1        1    1           1
#          Annet                 4        4        4    4           4
# 3        Annet                 8        7        7    8           8

# %%
data = pd.DataFrame(optics_found.groupby(['Clusters', 'PHDIAG']).size()).unstack(fill_value=0)
data.plot(kind='bar',figsize=(15, 8), xlabel='Clusters', ylabel='Count')
plt.legend(['AL amyloidose', 'Annet', 'TTR amyloidose'])
plt.savefig(os.path.join(results_dir, 'optics_clusters'))
